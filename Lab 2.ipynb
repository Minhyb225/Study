# %%
name = "Write your name here"
date_returned = "Write the date returned here"

# %% [markdown]
# # Lab 2
# **Graphical representation of functions**<br>
# Software 1<br>
# Information and Communication Technology<br>
# Metropolia University of Applied Sciences
#
# ## Instructions
#
# In these second exercises we
# - continue learning using numerical python to calculate numerical arrays that represents the functions and their values
# - use matplotlib graphical library to sketch several funcions in the same graph, and
# - lastly learn to solve mathematical equations graphically.
#
# Links to the documentation of the new functions:
# - [numpy.linspace](https://numpy.org/doc/stable/reference/generated/numpy.linspace.html)
# - [pyplot.legend](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html)
# - [How to label a line in matplotlib](https://www.tutorialspoint.com/how-to-label-a-line-in-matplotlib-python)
# - [pyplot.subplots](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html)
#
# You can use [Moodle Quiz Lab 2](https://moodle.metropolia.fi/mod/quiz/view.php?id=482766) to automatically check and verify your answers.

# %% [markdown]
# ## Setup
#
# Read necessary libraries. Notice that you need to import these libraries only once in the Notebook environment.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Problem 1
#
# Create a *linearly spaced numerical array* of $x$ from $0$ to $10$ having $100$ samples.

# %%
x = np.linspace(0, 10, 100)
print(x)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
#   7.87878788  7.97979798  8.08080808  8.18181818  8.28282828  8.38383838
#   8.48484848  8.58585859  8.68686869  8.78787879  8.88888889  8.98989899
#   9.09090909  9.19191919  9.29292929  9.39393939  9.49494949  9.5959596
#   9.6969697   9.7979798   9.8989899  10.        ]

# %% [markdown]
# ## Problem 2
#
# Using the *lineary spaced numerical array* of $x$ from $0$ to $10$ having $100$ samples, draw a graph of the function $y = (x-2)\cdot(x-8)$.
#
# Annotate the graph:
# - Add grid lines to the graph
# - Add label for the x axis: "x-axis"
# - add label for the y axis: "y-axis"
# - Add title for the graph: "Polynomial function"

# %%
x = np.linspace(0, 10, 100)
y = (x-2)*(x-8)

plt.plot(x, y)
plt.grid(True)
plt.title('Polynomial function')
plt.xlabel('x-axis')
plt.ylabel('y-axis');

# Graphics commands

# %% [markdown]
# ## Problem 3
#
# Using linearly spaced numerical array of $x$ from $0$ to $10$ having $100$ samples draw in the same graph two polynomials $y1 = (x-2)\cdot(x-8)$ and $y2 = (x-2)\cdot(x-5)\cdot(x-8)$.

# %%
x = np.linspace(0, 10, 100)
y1 = (x-2)*(x-8)
y2 = (x-2)*(x-5)*(x-8)

plt.plot(x, y1)
plt.plot(x, y2)
plt.grid(True)
plt.title('Polynomial function')
plt.xlabel('x-axis')
plt.ylabel('y-axis');

# %% [markdown]
# ## Problem 4
#
# Using linearly spaced numerical array of $x$ from $0$ to $10$ having $100$ samples draw in the same graph two polynomials $y1 = (x-2)\cdot(x-8)$ and $y2 = (x-2)\cdot(x-5)\cdot(x-8)$. (same as in previous problem).
#
# Annotate the graph:
# - Add labels 'y1' and 'y2' to the plots.
# - Add grid lines to the graph.
# - Add x-label: 'x-axis'.
# - Add y-label: 'y-axis'.
# - Add title: 'Polynomial functions'.
# - Add legend to the the graph.

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 10, 100)
y1 = (x-2)*(x-8)
y2 = (x-2)*(x-5)*(x-8)

plt.plot(x, y1, label='$(x-2)*(x-8)$')
plt.plot(x, y2, label='$(x-2).(x-5).(x-8)$')
plt.grid(True)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Polynomial function')
ax.legend();

# %% [markdown]
# ## Problem 5
#
# Using linearly spaced numerical array of $x$ from $0$ to $10$ having $100$ samples calculate the values for the two polynomials $y1 = (x-2)\cdot(x-8)$ and $y2 = (x-2)\cdot(x-5)\cdot(x-8)$. (same as in previous problem).
#
# Using two subplots, plot the first polynomial on the first axes and then the second polynomial on the second axes.
# - Use figure size of (6, 8).
#
# Annotate the graph:
# - Add grid lines to both plots.
# - Add title: 'y1' to the first subplot.
# - Add title: 'y2' to the second subplot.
# - Add x-label: 'x-axis' to the second plot.

# %%
fig, ax = plt.subplots(2, figsize = (6,8))
x = np.linspace(0, 10, 100)
y1 = (x-2)*(x-8)
ax[0].plot(x, y1, color = 'b', label='$(x-2)*(x-8)$')
ax[0].grid(True)
ax[0].set_xlabel('x-axis')
ax[0].set_ylabel('y-axis')
ax[0].set_title('Polynomial function')
ax[0].legend();

y2 = (x-2)*(x-5)*(x-8)
ax[1].plot(x, y2, color = 'r', label='$(x-2).(x-5).(x-8)$')
ax[1].grid(True)
ax[1].set_xlabel('x-axis')
ax[1].set_ylabel('y-axis')
ax[1].set_title('y2')
ax[1].legend();

# %% [markdown]
# ## Problem 6
#
# - Calculate values for functions $f(x) = \sqrt{2x}$ and $g(x) = 5 - x$. Use linearly spaced numerical array of $x$ from $0$ to $10$ having 100 samples.
# - Use two subplots and figure size of (6, 8).
# - Draw the full graphs of both functions into the first axes. This part of the graph shows the full graphs.
# - Draw the full graphs of both functions also into the second axes. This part is used for zooming in to the details.
# - Add grid lines to both subplots.
# - Change the x-axis and y-axis limits for the second axes, so that you can find graphically the intersection point (x0, y0) for the two equations (e.g. when $f(x) = g(x)$). Try to get the value minimum three significant figures accuracy.
# - Read the intersection point (x0, y0) from the graph and draw it to the second graph using red circle.

# %%
fig, ax = plt.subplots(2, figsize = (6, 8))
x = np.linspace(0, 10, 100)
f = np.sqrt(2*x)
g = 5 - x


ax[0].plot(x, f, color = 'b', label = '$sqrt(2x)$')
ax[0].plot(x, g, color = 'r', label = '$(5 - x)$')
ax[0].grid(True)
ax[0].set_xlabel('f-axis')
ax[0].set_ylabel('g-axis')
ax[0].set_title('First Axes')
ax[0].legend()



ax[1].plot(x, f, color = 'b', label = '$sqrt(2x)$')
ax[1].plot(x, g, color = 'r', label = '$(5 - x)$')
ax[1].grid(True)
ax[1].set_xlabel('f-axis')
ax[1].set_ylabel('g-axis')
ax[1].set_title('Second Axes')
ax[1].set_xlim(2.66,2.71)
ax[1].set_ylim(2.25,2.4)
ax[1].legend()


# Intercation point
x0 = 2.68356
y0 = 2.317
ax[1].plot(x0, y0, 'ro')
